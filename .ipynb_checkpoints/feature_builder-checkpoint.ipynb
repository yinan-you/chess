# %%
import os

# Point JAVA_HOME to your Java 17
os.environ["JAVA_HOME"] = "/opt/homebrew/Cellar/openjdk@17/17.0.16/libexec/openjdk.jdk/Contents/Home"

# Update PATH so 'java' command uses Java 17
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]

# Check
# !java -version
# Out:
# openjdk version "17.0.16" 2025-07-15
# OpenJDK Runtime Environment Homebrew (build 17.0.16+0)
# OpenJDK 64-Bit Server VM Homebrew (build 17.0.16+0, mixed mode, sharing)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, ArrayType, BooleanType

spark = SparkSession.builder \
    .appName("chess-ingest") \
    .getOrCreate()

# %%
import requests
import zstandard as zstd
import chess.pgn
import io
from tqdm.notebook import tqdm
import pandas as pd

url = "https://database.lichess.org/standard/lichess_db_standard_rated_2025-10.pgn.zst"

rows = []

def extract_moves(game):
    moves = []
    node = game
    while node.variations:
        node = node.variations[0]
        moves.append(node.move.uci())
    return moves

def game_has_evals(game):
    node = game
    while node.variations:
        node = node.variations[0]
        if node.comment and "%eval" in node.comment:
            return True
    return False

with requests.get(url, stream=True) as r:
    r.raise_for_status()
    dctx = zstd.ZstdDecompressor()
    with dctx.stream_reader(r.raw) as reader:
        text_stream = io.TextIOWrapper(reader, encoding="utf-8")

        # Create a generator for all games
        games_iter = iter(lambda: chess.pgn.read_game(text_stream), None)

        # Wrap the iterator in tqdm for a live progress bar
        for i, game in enumerate(tqdm(games_iter, desc="Parsing games", unit="games")):
            if game is None:
                break
            if i >= 50000000:  # limit for demo
                break

            headers = game.headers
            moves = extract_moves(game)

            row = {
                "white_rating": int(headers.get("WhiteElo", 0)),
                "black_rating": int(headers.get("BlackElo", 0)),
                "time_control": headers.get("TimeControl"),
                "opening": headers.get("Opening"),
                "result": headers.get("Result"),
                "moves": moves,
                "move_count": len(moves),
                "has_evals": game_has_evals(game)
            }

            rows.append(row)

# Define schema matching your extracted rows
schema = StructType([
    StructField("white_rating", IntegerType(), True),
    StructField("black_rating", IntegerType(), True),
    StructField("time_control", StringType(), True),
    StructField("opening", StringType(), True),
    StructField("result", StringType(), True),
    StructField("moves", ArrayType(StringType()), True),
    StructField("move_count", IntegerType(), True),
    StructField("has_evals", BooleanType(), True)
])

# Convert your list of dicts to Spark DataFrame
sdf = spark.createDataFrame(rows, schema=schema)
# Out:
# Parsing games: 0games [00:00, ?games/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 38
#      35 games_iter = iter(lambda: chess.pgn.read_game(text_stream), None)
#      37 # Wrap the iterator in tqdm for a live progress bar
# ---> 38 for i, game in enumerate(tqdm(games_iter, desc="Parsing games", unit="games")):
#      39     if game is None:
#      40         break
#
# File /opt/miniconda3/envs/chessenv/lib/python3.11/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     for obj in it:
#     251         # return super(tqdm...) will not catch exception
#     252         yield obj
#     253 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File /opt/miniconda3/envs/chessenv/lib/python3.11/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# Cell In[26], line 35, in <lambda>()
#      32 text_stream = io.TextIOWrapper(reader, encoding="utf-8")
#      34 # Create a generator for all games
# ---> 35 games_iter = iter(lambda: chess.pgn.read_game(text_stream), None)
#      37 # Wrap the iterator in tqdm for a live progress bar
#      38 for i, game in enumerate(tqdm(games_iter, desc="Parsing games", unit="games")):
#
# File /opt/miniconda3/envs/chessenv/lib/python3.11/site-packages/chess/pgn.py:1754, in read_game(handle, Visitor)
#    1752             else:
#    1753                 visitor.visit_move(board_stack[-1], move)
# -> 1754                 board_stack[-1].push(move)
#    1755         visitor.visit_board(board_stack[-1])
#    1757 if fresh_line:
#
# File /opt/miniconda3/envs/chessenv/lib/python3.11/site-packages/chess/__init__.py:2371, in Board.push(self, move)
#    2369 assert piece_type is not None, f"push() expects move to be pseudo-legal, but got {move} in {self.board_fen()}"
#    2370 capture_square = move.to_square
# -> 2371 captured_piece_type = self.piece_type_at(capture_square)
#    2373 # Update castling rights.
#    2374 self.castling_rights &= ~to_bb & ~from_bb
#
# File /opt/miniconda3/envs/chessenv/lib/python3.11/site-packages/chess/__init__.py:835, in BaseBoard.piece_type_at(self, square)
#     832     else:
#     833         return None
# --> 835 def piece_type_at(self, square: Square) -> Optional[PieceType]:
#     836     """Gets the piece type at the given square."""
#     837     mask = BB_SQUARES[square]
#
# KeyboardInterrupt:

# %%
sdf.select("white_rating", "black_rating").show(5)
# Out:
# +------------+------------+
# |white_rating|black_rating|
# +------------+------------+
# |        1217|        1232|
# |        2322|        2202|
# |        1533|        1525|
# |        1313|        1291|
# |        1358|        1436|
# +------------+------------+
# only showing top 5 rows
