# %%
import os

# Point JAVA_HOME to your Java 17
os.environ["JAVA_HOME"] = "/opt/homebrew/Cellar/openjdk@17/17.0.16/libexec/openjdk.jdk/Contents/Home"

# Update PATH so 'java' command uses Java 17
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]

# Check
# !java -version
# Out:
# openjdk version "17.0.16" 2025-07-15
# OpenJDK Runtime Environment Homebrew (build 17.0.16+0)
# OpenJDK 64-Bit Server VM Homebrew (build 17.0.16+0, mixed mode, sharing)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, ArrayType, BooleanType

spark = SparkSession.builder \
    .appName("LichessPGN") \
    .config("spark.driver.memory", "16g") \
    .config("spark.executor.memory", "16g") \
    .getOrCreate()

# %%
import requests
import zstandard as zstd
import chess.pgn
import io
from tqdm.notebook import tqdm
import pandas as pd

url = "https://database.lichess.org/standard/lichess_db_standard_rated_2025-10.pgn.zst"

rows = []

def extract_moves(game):
    moves = []
    node = game
    while node.variations:
        node = node.variations[0]
        moves.append(node.move.uci())
    return moves

def game_has_evals(game):
    node = game
    while node.variations:
        node = node.variations[0]
        if node.comment and "%eval" in node.comment:
            return True
    return False

with requests.get(url, stream=True) as r:
    r.raise_for_status()
    dctx = zstd.ZstdDecompressor()
    with dctx.stream_reader(r.raw) as reader:
        text_stream = io.TextIOWrapper(reader, encoding="utf-8")

        # Create a generator for all games
        games_iter = iter(lambda: chess.pgn.read_game(text_stream), None)

        # Wrap the iterator in tqdm for a live progress bar
        for i, game in enumerate(tqdm(games_iter, desc="Parsing games", unit="games")):
            if game is None:
                break
            if i >= 5000000:  # limit for demo
                break

            headers = game.headers
            moves = extract_moves(game)

            row = {
                "white_rating": int(headers.get("WhiteElo", 0)),
                "black_rating": int(headers.get("BlackElo", 0)),
                "time_control": headers.get("TimeControl"),
                "opening": headers.get("Opening"),
                "result": headers.get("Result"),
                "moves": moves,
                "move_count": len(moves),
                "has_evals": game_has_evals(game)
            }

            rows.append(row)

# Convert to pandas DataFrame (or Spark later)
df = pd.DataFrame(rows)
df.head()
# Out:
# Parsing games: 0games [00:00, ?games/s]
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x111e47490>>
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/chessenv/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 781, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 38
#      35 games_iter = iter(lambda: chess.pgn.read_game(text_stream), None)
#      37 # Wrap the iterator in tqdm for a live progress bar
# ---> 38 for i, game in enumerate(tqdm(games_iter, desc="Parsing games", unit="games")):
#      39     if game is None:
#      40         break
#
# File /opt/miniconda3/envs/chessenv/lib/python3.11/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     for obj in it:
#     251         # return super(tqdm...) will not catch exception
#     252         yield obj
#     253 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File /opt/miniconda3/envs/chessenv/lib/python3.11/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# Cell In[31], line 35, in <lambda>()
#      32 text_stream = io.TextIOWrapper(reader, encoding="utf-8")
#      34 # Create a generator for all games
# ---> 35 games_iter = iter(lambda: chess.pgn.read_game(text_stream), None)
#      37 # Wrap the iterator in tqdm for a live progress bar
#      38 for i, game in enumerate(tqdm(games_iter, desc="Parsing games", unit="games")):
#
# File /opt/miniconda3/envs/chessenv/lib/python3.11/site-packages/chess/pgn.py:1748, in read_game(handle, Visitor)
#    1746 if visitor.begin_parse_san(board_stack[-1], token) is not SKIP:
#    1747     try:
# -> 1748         move = visitor.parse_san(board_stack[-1], token)
#    1749     except ValueError as error:
#    1750         visitor.handle_error(error)
#
# File /opt/miniconda3/envs/chessenv/lib/python3.11/site-packages/chess/pgn.py:1121, in BaseVisitor.parse_san(self, board, san)
#    1107 def parse_san(self, board: chess.Board, san: str) -> chess.Move:
#    1108     """
#    1109     When the visitor is used by a parser, this is called to parse a move
#    1110     in standard algebraic notation.
#    (...)   1119         they can be handled for everyone.
#    1120     """
# -> 1121     return board.parse_san(san)
#
# File /opt/miniconda3/envs/chessenv/lib/python3.11/site-packages/chess/__init__.py:3206, in Board.parse_san(self, san)
#    3202         raise AmbiguousMoveError(f"ambiguous san: {san!r} in {self.fen()}")
#    3204     matched_move = move
# -> 3206 if not matched_move:
#    3207     raise IllegalMoveError(f"illegal san: {san!r} in {self.fen()}")
#    3209 return matched_move
#
# File /opt/miniconda3/envs/chessenv/lib/python3.11/site-packages/chess/__init__.py:676, in Move.__bool__(self)
#     673 def xboard(self) -> str:
#     674     return self.uci() if self else "@@@@"
# --> 676 def __bool__(self) -> bool:
#     677     return bool(self.from_square or self.to_square or self.promotion or self.drop)
#     679 def __repr__(self) -> str:
#
# KeyboardInterrupt:

# %%
sdf.select("white_rating", "black_rating").show(5)
# Out:
# +------------+------------+
# |white_rating|black_rating|
# +------------+------------+
# |        1217|        1232|
# |        2322|        2202|
# |        1533|        1525|
# |        1313|        1291|
# |        1358|        1436|
# +------------+------------+
# only showing top 5 rows
